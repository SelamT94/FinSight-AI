# %% [markdown]
# # 05 — Next.js frontend + FastAPI (Section 5)

# %%
import urllib.request

try:
    print(urllib.request.urlopen("http://127.0.0.1:8000/health", timeout=2).read().decode())
except Exception as e:
    print("API not reachable:", e)
# Out:
# {"status":"ok","root":"/mnt/data-disk/FinSight/FinSight-AI"}
